# %% [markdown]
# # Задачи:
# ## 1	Дайте определение matplotlib в свободной форме.
# ## 2	Определения Figure, Axes, Spines.
# ## 3	Есть два списка. Напишите код для построения графика: import matplotlib.pyplot as plt year = [1950, 1975, 2000, 2018] population = [2.12, 3.681,5.312, 6.981]

# %% [markdown]
# 1. Matplotlib — библиотека на языке программирования Python для визуализации данных двумерной и трёхмерной графикой. Получаемые изображения могут быть использованы в качестве иллюстраций в публикациях.

# %%
import matplotlib.pyplot as plt
plt.plot([1950, 1975, 2000, 2018],[2.12, 3.681,5.312, 6.981] )
plt.xlabel('year')
plt.ylabel('population bil.')
plt.show()

# %% [markdown]
# # Задачи:
# ## 1	Дайте описание библиотеки Seaborn.
# ## 2	Как нарисовать гистограмму в Seaborn?
# ## 3	Подумайте, что нужно сделать, чтобы построенная гистограмма стала
# горизонтальной?
# ## 4 Какие нужно применить параметры, чтобы задать цвет графика?

# %% [markdown]
# 1. Seaborn — это библиотека для создания статистических графиков на Python. Она основывается на matplotlib и тесно взаимодействует со структурами данных pandas.
# 2. Для построения гистограммы в Seaborn выполните следующие шаги:
# Подготовьте данные. Создайте набор данных, который хотите проанализировать. Это может быть список, массив или серия числовых данных Pandas.
# Используйте функцию sns.histplot(). Это основная функция в Seaborn для создания гистограммы. Передайте данные этой функции.
# Отобразите график. Используйте функцию plt.show() для отображения графика.
# 3. Чтобы создать горизонтальную гистограмму, нам просто нужно передать категориальную переменную в аргумент y и числовую переменную в аргумент x :
# 4. Аргумент palette=[" цвет", ..., " цвет "]

# %% [markdown]
# # Задачи:
# ## 1	Что позволяет делать библиотека Plotly?
# ## 2	Назовите основные преимущества этой библиотеки перед аналогичными?
# ## 3	Какие диаграммы позволяет рисовать данная библиотека?

# %% [markdown]
# 1. Cтроить интерактивные визуализации
# 2. Plotly — бесплатная библиотека, которую вы можете использовать в коммерческих целях
# Plotly работает offline
# Plotly позволяет строить интерактивные визуализации
# Т.е. с помощью Plotly можно как изучать какие-то данные «на лету» (не перестраивая график в matplotlib, изменяя масштаб, включая/выключая какие-то данные), так и построить полноценный интерактивный отчёт (дашборд).
# 3. Поддерживает различные графики, такие как линейные диаграммы, точечные диаграммы, столбчатые диаграммы, гистограммы, площадные графики и т.д.
