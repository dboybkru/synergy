# %% [markdown]
# <img src="sklearn.PNG">

# %% [markdown]
# ## I.Standart Scaler

# %%
from sklearn import preprocessing
import numpy as np
X_train = np.array([[ 10., -10.,  20.],
                    [ 20.,  0.,  0.  ],
                    [ 0.,  10., -10.]])

# %%
X_train.std()
# Out:
# 10.657403385139377

# %%
X_train.mean()
# Out:
# 4.444444444444445

# %%
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
X_transformed = scaler.transform(X_train)
X_transformed
# Out:
# array([[ 0.        , -1.22474487,  1.33630621],
#        [ 1.22474487,  0.        , -0.26726124],
#        [-1.22474487,  1.22474487, -1.06904497]])

# %%
X_train.std()
# Out:
# 10.657403385139377

# %%
X_transformed.std()
# Out:
# 1.0

# %%
X_train.mean(axis=0)
# Out:
# array([10.        ,  0.        ,  3.33333333])

# %%
X_transformed.mean(axis=0)
# Out:
# array([0., 0., 0.])

# %%
"""
Возьмем сэмпл побольше
"""
import matplotlib.pyplot as plt
sample = np.random.randn(100,10)*5 + 20

plt.figure(figsize=(25,10))
plt.grid()
violin_parts = plt.violinplot(sample[:,:], showmedians=True)
for pc in violin_parts['bodies']:
    pc.set_facecolor('red')
    
scaled_sample = preprocessing.StandardScaler().fit_transform(sample)

violin_parts = plt.violinplot(scaled_sample[:,:], showmedians=True)
for pc in violin_parts['bodies']:
    pc.set_facecolor('green')

# %% [markdown]
# ## II Scaling to a range

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(X_train)
X_train_minmax
# Out:
# array([[0.5       , 0.        , 1.        ],
#        [1.        , 0.5       , 0.33333333],
#        [0.        , 1.        , 0.        ]])

# %%
min_max_scaler = preprocessing.MinMaxScaler((-5, 5))
X_train_minmax = min_max_scaler.fit_transform(X_train)
X_train_minmax
# Out:
# array([[ 0.        , -5.        ,  5.        ],
#        [ 5.        ,  0.        , -1.66666667],
#        [-5.        ,  5.        , -5.        ]])

# %%
import matplotlib.pyplot as plt
sample = np.random.randn(100,10)*5 + 20

plt.figure(figsize=(25,10))
plt.grid()
violin_parts = plt.violinplot(sample[:,:], showmedians=True)
for pc in violin_parts['bodies']:
    pc.set_facecolor('red')
    
scaled_sample_1 = preprocessing.MinMaxScaler((-10,5)).fit_transform(sample)
scaled_sample_2 = preprocessing.MinMaxScaler((-5,10)).fit_transform(sample)

violin_parts = plt.violinplot(scaled_sample_1[:,:], showmedians=True)
for pc in violin_parts['bodies']:
    pc.set_facecolor('green')
    
violin_parts = plt.violinplot(scaled_sample_2[:,:], showmedians=True)
for pc in violin_parts['bodies']:
    pc.set_facecolor('blue')

# %% [markdown]
# ## III Mapping to a Uniform distribution

# %%
quantile_transformer = preprocessing.QuantileTransformer(random_state=0)

# %%
sample = np.random.randn(100,10)

# %%
sample_transformed = quantile_transformer.fit_transform(sample)
# Out:
# C:\Users\Sergei\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2367: UserWarning: n_quantiles (1000) is greater than the total number of samples (100). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "

# %%
quantiles = np.arange(100)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,10))
plt.grid()

plt.plot(quantiles, np.percentile(sample_transformed[:,0], quantiles), label='Transformed data')
plt.plot(quantiles, np.percentile(sample[:,0], quantiles), label = 'Original data')
plt.legend()

# %% [markdown]
# ## Or normal

# %%
quantile_transformer = preprocessing.QuantileTransformer(output_distribution='normal', random_state=0)

# %%
sample = np.random.triangular(0,1,3,size=(10000,10))

# %%
sample_transformed = quantile_transformer.fit_transform(sample)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,10))
plt.grid()

plt.plot(quantiles, np.percentile(sample_transformed[:,0], quantiles), label='Transformed data')
plt.plot(quantiles, np.percentile(sample[:,0], quantiles), label = 'Original data')
plt.legend()

# %%
plt.figure(figsize=(25,10))
plt.grid()
plt.violinplot(sample)
plt.violinplot(sample_transformed)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x290919ff9d0>,
#   <matplotlib.collections.PolyCollection at 0x290919ffcd0>,
#   <matplotlib.collections.PolyCollection at 0x290919fffd0>,
#   <matplotlib.collections.PolyCollection at 0x29091a11310>,
#   <matplotlib.collections.PolyCollection at 0x29091a11610>,
#   <matplotlib.collections.PolyCollection at 0x29091a11910>,
#   <matplotlib.collections.PolyCollection at 0x29091a11c10>,
#   <matplotlib.collections.PolyCollection at 0x29091a11f10>,
#   <matplotlib.collections.PolyCollection at 0x29091a1c250>,
#   <matplotlib.collections.PolyCollection at 0x29091a1c550>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x290919ff880>,
#  'cmins': <matplotlib.collections.LineCollection at 0x29091a1cbb0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x29091a300a0>}

# %% [markdown]
# ## IV Normalize

# %%
X = np.random.randn(1000,1)*1.5
normalizer_l2 = preprocessing.Normalizer(norm='l2').fit(X)
normalizer_l1 = preprocessing.Normalizer(norm='l1').fit(X)
X_norm_l2 = normalizer_l2.transform(X)
X_norm_l1 = normalizer_l1.transform(X)
plt.figure(figsize=(25,10))
plt.grid()
plt.violinplot(X)
plt.violinplot(X_norm_l2)
#plt.violinplot(X_norm_l1)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x29091b100d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x29091b022b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x29091b10580>,
#  'cbars': <matplotlib.collections.LineCollection at 0x29091b10880>}

# %%
X = np.random.triangular(-3,2,3,size=(1000,1))#*1.5
normalizer_l2 = preprocessing.Normalizer(norm='l2').fit(X)
normalizer_l1 = preprocessing.Normalizer(norm='l1').fit(X)
X_norm_l2 = normalizer_l2.transform(X)
X_norm_l1 = normalizer_l1.transform(X)
plt.figure(figsize=(25,10))
plt.grid()
plt.violinplot(X)
plt.violinplot(X_norm_l2)
plt.violinplot(X_norm_l1)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x29091b7afd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x29091b7aeb0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x29091b87520>,
#  'cbars': <matplotlib.collections.LineCollection at 0x29091b87820>}

# %% [markdown]
# ## V Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_full = np.array([[[x,y] for y in np.linspace(-np.sqrt(9 - x**2), np.sqrt(9 - x**2),50)] for x in np.arange(-3,3,0.01)])

# %%
X_full.shape
# Out:
# (600, 50, 2)

# %%
plt.figure(figsize=(15,15))
plt.grid()
plt.scatter(X_full.reshape(-1,2)[:,0], X_full.reshape(-1,2)[:,1])

# %%
X_train, x_test,y_train , y_test = train_test_split(X_full, X_full, test_size=0.2, shuffle=False)

# %%
plt.figure(figsize=(15,15))
plt.grid()
plt.scatter(X_train.reshape(-1,2)[:,0], X_train.reshape(-1,2)[:,1])
plt.scatter(x_test.reshape(-1,2)[:,0], x_test.reshape(-1,2)[:,1])

# %%
X_train, x_test,y_train , y_test = train_test_split(X_full, X_full, test_size=0.2, shuffle=True)

# %%
plt.figure(figsize=(15,15))
plt.grid()


plt.scatter(x_test.reshape(-1,2)[:,0], x_test.reshape(-1,2)[:,1], c='r')
plt.scatter(X_train.reshape(-1,2)[:,0], X_train.reshape(-1,2)[:,1], c='b')
