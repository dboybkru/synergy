# %% [markdown]
# # Задачи:
# ## 1	Что представляет собой библиотека SciPy?
# ## 2	В чём отличия и сходства NumPy и SciPy?
# ## 3	Перечислите основной набор пакетов для научных вычислений.

# %% [markdown]
# 1. SciPy – это бесплатная программная библиотека с открытым исходным кодом, используемая для научных вычислений на языке Python. SciPy используется в инженерии, естественных науках, а также математических вычислениях. SciPy подходит для таких задач, как анализ данных, визуализация данных и численные вычисления.
# 2. NumPy и SciPy — это две важные библиотеки Python для численных вычислений, но они служат разным целям.
# NumPy фокусируется на быстрой обработке и подходит для основных концепций массивов. Он в основном работает с многомерными объектами массивов, эффективно отслеживая тип данных, форму и размер.
# SciPy предлагает детальные версии функций для глубоких численных вычислений. Он построен на основе NumPy и предлагает широкий спектр инструментов для сложных задач, таких как решение дифференциальных уравнений, оптимизация, статистический анализ и специализированные математические функции.
# Выбор между NumPy и SciPy зависит от поставленной задачи. NumPy предпочтительнее для базовых вычислительных операций, манипуляций с массивами и элементарных математических вычислений, а SciPy подходит для продвинутых вычислительных процедур, статистического тестирования и разнообразных функций, таких как обработка изображений и градиентная оптимизация.
# 3. MATLAB, GNU Octave и SciLab "Наиболее распространённый среди научных работников пакет программ носит название MATLAB. Также существуют бесплатные пакеты программ, которые решают практически те же задачи: GNU Octave и SciLab. Кроме того, если нужно получить решение математической задачи в алгебраическом виде, учёные используют Mathematica, MathCAD, Maple."

# %% [markdown]
# # Задачи:
# ## 1	Опишите метод describe. Что необходимо по логике первым сделать с предоставленными данными в статистике?
# ## 2	Что можно сделать дальше?
# ## 3	Следующий шаг...

# %% [markdown]
# 1. метод describe() в Python Pandas используется для вычисления описательных статистических данных, таких как количество, уникальные значения, среднее значение, стандартное отклонение, минимальное и максимальное значение и многое другое.
# В двух словах, описательная статистика предназначена для описания фрагмента необработанных данных с использованием сводной статистики, графиков и таблиц.
# Логично для начала вычислить средние значаения и построить график который поможет нам визуализировать распределение значений.
# 2. Визуализировать график, построить таблицы, что бы получить представление о распределении значений.
# 3.

# %% [markdown]
# # Задачи:
# ## 1	Что представляет собой библиотека Scikit-leam?
# ## 2	Обучение с учителем - определение
# ## 3	Чем характеризуется обучение без учителя?
# ## 4	Какие библиотеки содержит в себе Scikit-learn?

# %% [markdown]
# 1. Scikit-learn — Python-библиотека для машинного обучения. Её цель — взаимодействие с числовыми и научными библиотеками Python: NumPy и SciPy. В библиотеке представлены различные алгоритмы классификации, регрессии и кластеризации, включая support vector machines, random forests, gradient boosting, k-means и DBSCAN.
# 2. Подход, при котором машине заранее дают понять, какой ответ будет считаться правильным. Под учителем здесь понимается обучающая выборка с размеченными нужным образом данными либо тот, кто указывает правильные ответы в процессе обучения. На основе предоставленных учителем данных машина сама находит и определяет признаки, позволяющие ей, условно, отличить кошку от собаки или мужчину от женщины. В дальнейшем обученный алгоритм можно перенастроить на решение других задач.
# 3. Работа нейросети с большим объёмом неразмеченных данных. В процессе работы нейросеть сама старается найти в них общие признаки исвязи.
# 4.

# %% [markdown]
# # Задачи:
# ## 1	Приведите краткое описание statsmodels
# ## 2	Повторите за спикером работу с statsmodels как можно более подробно. Предоставьте скриншоты с процессом выполнения

# %% [markdown]
# 1. Statsmodels — это библиотека с открытым исходным кодом на Python, которая фокусируется на статистическом моделировании и эконометрике.
# Основные функции Statsmodels включают:
# Регрессионный анализ.
# Анализ временных рядов.
# Тестирование гипотез.
# Анализ ANOVA и экспериментальный дизайн.
# Интеграция с библиотеками машинного обучения.
# 2. ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
